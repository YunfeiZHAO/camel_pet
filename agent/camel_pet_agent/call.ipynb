# %%
print('ok')
# Out:
# ok

# %%
import os

os.environ["ANTHROPIC_BASE_URL"] = "https://api.minimax.io/anthropic"
os.environ["ANTHROPIC_API_KEY"] = "sk-cp-OWW0CmM-GKvrrWSgi6OYwiOtaGT4onu-9pTMSeyKoo8GWl6HZJvluu8Csqmwh8kgFgRYpypKdWFe9c6lMFcABHTQdr4KlY2rT60SknX01RpiOtBpmCeJwFQ"

# %%
import anthropic

client = anthropic.Anthropic()

message = client.messages.create(
    model="MiniMax-M2.7",
    max_tokens=1000,
    system="You are a helpful assistant.",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Hi, how are you?"
                }
            ]
        }
    ]
)

for block in message.content:
    if block.type == "thinking":
        print(f"Thinking:\n{block.thinking}\n")
    elif block.type == "text":
        print(f"Text:\n{block.text}\n")
# Out:
# Thinking:
# The user is greeting me casually, asking how I am. This is a simple conversational opening. I should respond in a friendly, concise manner.
#
# Text:
# Hi! I'm doing well, thanks for asking. How are you doing today? Is there something I can help you with?
